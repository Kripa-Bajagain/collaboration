# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
var=['a','b','c','d','e']
pd.Series(var)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
num=[10,20,30,40,50]
var=['a','b','c','d','e']
pd.Series(var,index=num)
# Out:
# 10    a
# 20    b
# 30    c
# 40    d
# 50    e
# dtype: object

# %%
print(pd.Series(var,index=num,name="Data Manipulation"))
# Out:
# 10    a
# 20    b
# 30    c
# 40    d
# 50    e
# Name: Data Manipulation, dtype: object

# %%
marks={
    'math':67,
    'english':57,
    'science':89
}
df=pd.DataFrame(marks,index=["Subjects"])
print(df)
# Out:
#           math  english  science
# Subjects    67       57       89

# %%
import pandas as pd
df=pd.read_csv("data.csv")
print(df.head(2))
# Out:
#   name  age  address profession
# 0    A   11    earth   engineer
# 1    B   12  mercury      pilot

# %%
print(df.dtypes)
# Out:
# name          object
# age            int64
# address       object
# profession    object
# dtype: object

# %%
print(df.describe())
# Out:
#              age
# count   4.000000
# mean   12.500000
# std     1.290994
# min    11.000000
# 25%    11.750000
# 50%    12.500000
# 75%    13.250000
# max    14.000000

# %%
df["profession"]=df["profession"].str.upper()
print(df)
# Out:
#   name  age  address profession
# 0    A   11    earth   ENGINEER
# 1    B   12  mercury      PILOT
# 2    C   13    venus   FRONTEND
# 3    D   14     mars    BACKEND

# %%
df.columns=df.columns.str.strip()
df["age"]=(df["age"]-df["age"].mean())/df["age"].std()
print(df)
# Out:
#   name       age  address profession
# 0    A -1.161895    earth   ENGINEER
# 1    B -0.387298  mercury      PILOT
# 2    C  0.387298    venus   FRONTEND
# 3    D  1.161895     mars    BACKEND

# %%
import pandas as pd
df=pd.read_csv('pandas_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
print(df.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(df['Name'])
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
print(df['Attack'])
print(df['HP'])
print(df['Defense'])
# Out:
# 0       49
# 1       62
# 2       82
# 3      100
# 4       52
#       ...
# 795    100
# 796    160
# 797    110
# 798    160
# 799    110
# Name: Attack, Length: 800, dtype: int64
# 0      45
# 1      60
# 2      80
# 3      80
# 4      39
#        ..
# 795    50
# 796    50
# 797    80
# 798    80
# 799    80
# Name: HP, Length: 800, dtype: int64
# 0       49
# 1       63
# 2       83
# 3      123
# 4       43
#       ...
# 795    150
# 796    110
# 797     60
# 798     60
# 799    120
# Name: Defense, Length: 800, dtype: int64

# %%
print(df['Name'][0:5])
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
print(df.iloc[1])
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
print(df.iloc[0:4])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
print(df.iloc[1,4])
# Out:
# 60

# %%
for index,row in df.iterrows():
    print(index,row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
df.loc[df['Type 1']=="Grass"]
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df=df.drop_duplicates()
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df=df.rename(columns={"Name":"how old"})
print(df)
# Out:
#        #                how old   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df=df.sort_values('Attack',ascending=False)
print(df)
# Out:
#        #                  how old   Type 1    Type 2   HP  Attack  Defense  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# ..   ...                      ...      ...       ...  ...     ...      ...
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 261  242                  Blissey   Normal       NaN  255      10       10
# 139  129                 Magikarp    Water       NaN   20      10       55
# 121  113                  Chansey   Normal       NaN  250       5        5
# 488  440                  Happiny   Normal       NaN  100       5        5
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df=df.sort_values(['Attack','HP'],ascending=[1,0])
print(df)
# Out:
#        #                  how old   Type 1    Type 2   HP  Attack  Defense  \
# 121  113                  Chansey   Normal       NaN  250       5        5
# 488  440                  Happiny   Normal       NaN  100       5        5
# 261  242                  Blissey   Normal       NaN  255      10       10
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 139  129                 Magikarp    Water       NaN   20      10       55
# ..   ...                      ...      ...       ...  ...     ...      ...
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df['Total']=df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']
df.head(5)
# Out:
#        #   how old  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  113   Chansey  Normal    NaN  250       5        5       35      105
# 488  440   Happiny  Normal    NaN  100       5        5       15       65
# 261  242   Blissey  Normal    NaN  255      10       10       75      135
# 230  213   Shuckle     Bug   Rock   20      10      230       10      230
# 139  129  Magikarp   Water    NaN   20      10       55       15       20
#
#      Speed  Generation  Legendary  Total
# 121     50           1      False    450
# 488     30           4      False    220
# 261     55           2      False    540
# 230      5           2      False    505
# 139     80           1      False    200

# %%
df.to_csv('new_data.csv')
print(df.to_csv)
# Out:
# <bound method NDFrame.to_csv of        #                  how old   Type 1    Type 2   HP  Attack  Defense  \
# 121  113                  Chansey   Normal       NaN  250       5        5
# 488  440                  Happiny   Normal       NaN  100       5        5
# 261  242                  Blissey   Normal       NaN  255      10       10
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 139  129                 Magikarp    Water       NaN   20      10       55
# ..   ...                      ...      ...       ...  ...     ...      ...
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
#
# ...

# %%
df.to_csv('new_data.csv',index=False)
print(df.to_csv)
# Out:
# <bound method NDFrame.to_csv of        #                  how old   Type 1    Type 2   HP  Attack  Defense  \
# 121  113                  Chansey   Normal       NaN  250       5        5
# 488  440                  Happiny   Normal       NaN  100       5        5
# 261  242                  Blissey   Normal       NaN  255      10       10
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 139  129                 Magikarp    Water       NaN   20      10       55
# ..   ...                      ...      ...       ...  ...     ...      ...
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
#
# ...

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
labels=['Group1','Group2','Group3','Group4','Group5']
men_age=[20,30,40,45,46]
women_age=[25,30,15,32,22]
fix,ax=plt.subplots()
ax.bar(labels,men_age,label='Men')
ax.bar(labels,women_age,bottom=men_age,label='Women')

ax.set_ylabel('Age')
ax.set_xlabel('Group Number')
ax.set_title('Gender Ratio by group')

ax.legend()
plt.show()

# %%
# Out:
# Text(0.5, 1.0, 'Gender Ratio by group')

# %%
import matplotlib.pyplot as plt
import numpy as np
classes=["Python","R","AI","ML","DS"]
class1_students=[30,40,50,20,33]
class2_students=[40,5,20,20,10]
class_index=np.arange(len(classes))
width=0.2
plt.bar(class_index,class1_students,width,label="class1 students")
plt.bar(class_index+width,class2_students,width,label="class2 students")
plt.xticks(class_index+width,classes)
plt.title("Bar Chart of classes")
plt.xlabel("classes")
plt.ylabel("no.of students")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
classes=["Python","R","AI","ML","DS"]
class1_students=[30,40,50,20,33]
class2_students=[40,5,20,20,10]
class_index=np.arange(len(classes))
width=0.2
plt.barh(class_index,class1_students,width,label="class1 students")
plt.barh(class_index+width,class2_students,width,label="class2 students")
plt.yticks(class_index+width,classes)
plt.title("Bar Chart of classes")
plt.xlabel("classes")
plt.ylabel("no.of students")
plt.show()

# %%
subject={
    "math":45,
    "english":60,
    "python":89
}
list1=list(subject.keys())
list2=list(subject.values())
plt.bar(list1,list2)
plt.show()

# %%
subject={
    "math":45,
    "english":60,
    "python":89
}
list1=list(subject.keys())
list2=list(subject.values())
plt.scatter(list1,list2)
plt.show()

# %%
subject={
    "math":45,
    "english":60,
    "python":89
}
list1=list(subject.keys())
list2=list(subject.values())
x=100
plt.scatter(list1,list2,x,marker=r'$\clubsuit$')
plt.show()

# %%
subject={
    "math":45,
    "english":60,
    "python":89
}
list1=list(subject.keys())
list2=list(subject.values())
x=400
plt.scatter(list1,list2,x,marker=r'$\alpha$')
plt.show()
